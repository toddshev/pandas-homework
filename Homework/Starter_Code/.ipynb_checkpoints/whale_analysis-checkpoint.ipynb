# %% [markdown]
#  #  A Whale off the Port(folio)
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from pathlib import Path
# %matplotlib inline

#constants
T_DAYS = 252  # Trading Days
IND = "S&P 500"  # Index to compare to

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
# 1. whale_returns.csv
# 2. algo_returns.csv
# 3. sp500_history.csv

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns

whale_returns_csv = Path("Resources/whale_returns.csv")
# YOUR CODE HERE
df_whale = pd.read_csv(whale_returns_csv,index_col = "Date", parse_dates = True, infer_datetime_format = True)
df_whale.sort_index(inplace = True)

# %%
# Count nulls
# YOUR CODE HERE
df_whale.isna().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
# YOUR CODE HERE
df_whale.dropna(inplace = True)
df_whale.isna().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_returns_csv = Path("Resources/algo_returns.csv")
# YOUR CODE HERE

df_algo = pd.read_csv(algo_returns_csv, index_col = "Date", parse_dates = True, infer_datetime_format = True)
df_algo.sort_index(inplace = True)
df_algo.tail()
# Out:
#               Algo 1    Algo 2
# Date
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358

# %%
# Count nulls
df_algo.isna().sum()
# YOUR CODE HERE
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
df_algo.dropna(inplace = True)
df_algo.isna().sum()
# YOUR CODE HERE
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P500 Historic Closing Prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_history_csv = Path("Resources/sp500_history.csv")
# YOUR CODE HERE
df_sp = pd.read_csv(sp500_history_csv,index_col = "Date", parse_dates = True, infer_datetime_format = True)

df_sp["Close"] = df_sp["Close"].str[1::]  #remove dollar sign
df_sp = df_sp.astype("float")
df_sp.sort_index(inplace = True)  # to ensure DR are calc'ed correctly

daily_returns_sp = df_sp.pct_change()
daily_returns_sp.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322

# %%
# Check Data Types
#PREVIOUSLY DONE

# %%
# Fix Data Types
# YOUR CODE HERE
#PREVIOUSLY DONE

# %%
# Calculate Daily Returns
# YOUR CODE HERE
#PREVIOUSLY DONE

# %%
# Drop nulls
# YOUR CODE HERE
daily_returns_sp.dropna(inplace = True)
daily_returns_sp.head()
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %%
# Rename Column
# YOUR CODE HERE
daily_returns_sp.rename(columns = {"Close":"S&P 500"}, inplace = True)

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Concatenate all DataFrames into a single DataFrame
# YOUR CODE HERE
daily_returns = pd.concat([df_whale,df_algo,daily_returns_sp],axis = "columns", join = "inner")
daily_returns.sort_index(inplace = True)
daily_returns.dropna(inplace = True)
cum_returns = (1+ daily_returns).cumprod()
cum_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                   0.998734            0.995019
# 2015-03-04                   1.000962            0.998245
# 2015-03-05                   1.004981            1.002314
# 2015-03-06                   0.997037            0.998731
# 2015-03-09                   0.997617            1.002951
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                     0.999504                0.993431  0.998058
# 2015-03-04                     0.996972                0.997617  0.989486
# 2015-03-05                     0.999319                1.004327  0.988541
# 2015-03-06                     0.990844                0.991172  0.983641
# 2015-03-09                     0.996633                0.989534  0.978283
#
#               Algo 2   S&P 500
# Date
# 2015-03-03  0.999051  0.995461
# 2015-03-04  1.001464  0.991093
# 2015-03-05  1.005794  0.992278
# 2015-03-06  0.994267  0.978214
# 2015-03-09  0.995563  0.982072

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance
#
# Calculate and Plot the daily returns and cumulative returns. Does any portfolio outperform the S&P 500?

# %%
# Plot daily returns
# YOUR CODE HERE
daily_returns.plot(figsize = [15,15], title = "Daily Returns")

# %%
# Plot cumulative returns
# YOUR CODE HERE
cum_returns.plot(figsize = [20,15], title = "Cumulative Returns")

# %% [markdown]
# ## Risk
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %%
# Box plot to visually show risk
# YOUR CODE HERE
daily_returns.plot.box(figsize = [20,12], title = "Boxplot of Standard Deviations")

# %%
# Daily Standard Deviations
# Calculate the standard deviation for each portfolio. 
# Which portfolios are riskier than the S&P 500?
# YOUR CODE HERE
#Several ways to do this - sort descending, slice the top 2, or compare with S&P
#I chose the latter as it's more transferrable, and also created a variable to test diff scenarios

dr_std = daily_returns.std()
dr_std.sort_values(ascending = False, inplace = True) #not needed, but makes for easier reading
risky = dr_std[dr_std > dr_std[IND]]
risky
# Out:
# BERKSHIRE HATHAWAY INC         0.012919
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# dtype: float64

# %%
# Determine which portfolios are riskier than the S&P 500
# YOUR CODE HERE
risky_bool = dr_std > dr_std[IND]
risky_bool

#Based on standard deviation of daily returns, a good proxy for risk, Berkshire Hathaway Inc and Tiger Global Management, LLC
#are both riskier than the S&P 500, which is the proxy for the Market.
# Out:
# BERKSHIRE HATHAWAY INC          True
# TIGER GLOBAL MANAGEMENT LLC     True
# S&P 500                        False
# Algo 2                         False
# SOROS FUND MANAGEMENT LLC      False
# Algo 1                         False
# PAULSON & CO.INC.              False
# dtype: bool

# %%
# Calculate the annualized standard deviation (252 trading days)
# YOUR CODE HERE
ann_std = dr_std * np.sqrt(T_DAYS)
ann_std
# Out:
# BERKSHIRE HATHAWAY INC         0.205077
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# S&P 500                        0.135786
# Algo 2                         0.132430
# SOROS FUND MANAGEMENT LLC      0.125335
# Algo 1                         0.120967
# PAULSON & CO.INC.              0.111488
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Plot the rolling standard deviation of the various portfolios along with the rolling standard deviation of the S&P 500 (consider a 21 day window). Does the risk increase for each of the portfolios at the same time risk increases in the S&P?
# 2. Construct a correlation table for the algorithmic, whale, and S&P 500 returns. Which returns most closely mimic the S&P?
# 3. Choose one portfolio and plot a rolling beta between that portfolio's returns and S&P 500 returns. Does the portfolio seem sensitive to movements in the S&P 500?
# 4. An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the ewm with a 21 day half-life.

# %%
# Calculate and plot the rolling standard deviation for
# the S&P 500 and whale portfolios using a 21 trading day window
# YOUR CODE HERE
win = 21
rolling_21 = daily_returns.rolling(window = win).std()
rolling_21.sort_index(inplace = True)
rolling_21.plot(figsize = [20,15], title = f"{win}-day Rolling St Dev of All Portfolios")

# %%
# Construct a correlation table
# YOUR CODE HERE
corr_table = daily_returns.corr()
corr_table
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# S&P 500                                       0.837864            0.669732
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# Algo 2                                          0.507414
# S&P 500                                         0.623946
#
#                              BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# SOROS FUND MANAGEMENT LLC                  0.754360  0.321211  0.826873
# PAULSON & CO.INC.                          0.545623  0.268840  0.678152
# TIGER GLOBAL MANAGEMENT LLC                0.424423  0.164387  0.507414
# BERKSHIRE HATHAWAY INC                     1.000000  0.292033  0.688082
# Algo 1                                     0.292033  1.000000  0.288243
# Algo 2                                     0.688082  0.288243  1.000000
# S&P 500                                    0.751371  0.279494  0.858764
#
#                               S&P 500
# SOROS FUND MANAGEMENT LLC    0.837864
# PAULSON & CO.INC.            0.669732
# TIGER GLOBAL MANAGEMENT LLC  0.623946
# BERKSHIRE HATHAWAY INC       0.751371
# Algo 1                       0.279494
# Algo 2                       0.858764
# S&P 500                      1.000000

# %%
sns.heatmap(corr_table,vmin = -1, vmax = 1)

# %%
# Calculate Beta for a single portfolio compared to the total market (S&P 500)
# (Your graph may differ, dependent upon which portfolio you are comparing)
# YOUR CODE HERE

ticker = "Algo 2"
win = 60

cov = daily_returns[ticker].cov(daily_returns[IND])
var = daily_returns[ticker].var()

beta = cov / var
beta

rolling_cov = daily_returns[ticker].rolling(window=win).cov(daily_returns[IND])
rolling_cov.sort_index(inplace = True)
rolling_var = daily_returns[IND].rolling(window=win).var()
rolling_var.sort_index(inplace = True)
rolling_beta = rolling_cov / rolling_var

rolling_beta.plot(figsize = [15,10], title = f"Rolling {win}-day Beta for {ticker.title()}")

# %%
# Calculate a rolling window using the exponentially weighted moving average. 
# YOUR CODE HERE  
daily_returns.ewm(halflife = 21).std().plot(figsize = (18,10))

# %% [markdown]
# ---

# %% [markdown]
# ## Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. (After all, if you could invest in one of two portfolios, each offered the same 10% return, yet one offered lower risk, you'd take that one, right?)
#
# 1. Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot.
# 2. Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.

# %%
# Calculate annualized Sharpe Ratios
# YOUR CODE HERE
sharpe = daily_returns.mean() / daily_returns.std() * np.sqrt(252)
sharpe
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# S&P 500                        0.648267
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
# YOUR CODE HERE
sharpe.plot.bar(figsize = [10,8])

# %% [markdown]
# On the basis of this performance metric, do our algo strategies outperform both 'the market' and the whales? Type your answer here: Since a positive Sharpe ratio indicates "alpha" (excess return), Algo 1 was by far the best performer.  Algo 2, while not outperforming the S&P 500 (Market), performed relatively well, in the middle of the pack as 4th best of 7.

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Returns
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Visit [Google Sheets](https://docs.google.com/spreadsheets/) and use the in-built Google Finance function to choose 3-5 stocks for your own portfolio.
# 2. Download the data as CSV files and calculate the portfolio returns.
# 3. Calculate the returns for each stock.
# 4. Using those returns, calculate the weighted returns for your entire portfolio assuming an equal number of shares for each stock.
# 5. Add your portfolio returns to the DataFrame with the other portfolios and rerun the analysis. How does your portfolio fair?
#
#
# ## Your analysis should include the following:
#
# - Using all portfolios:
#  - The annualized standard deviation (252 trading days) for all portfolios.
#  - The plotted rolling standard deviation using a 21 trading day window for all portfolios.
#  - The calculated annualized Sharpe Ratios and the accompanying bar plot visualization.
#  - A correlation table.
# - Using your custom portfolio and one other of your choosing:
#  - The plotted beta.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Read the first stock
# YOUR CODE HERE
csv_path = Path("../aapl.csv")
df_aapl = pd.read_csv(csv_path, index_col = 0, parse_dates = True, infer_datetime_format = True)
df_aapl.head()
# Out:
#             Close
# Date
# 2014-06-02  22.45
# 2014-06-03  22.77
# 2014-06-04  23.03
# 2014-06-05  23.12
# 2014-06-06  23.06

# %%
# Read the second stock
# YOUR CODE HERE
csv_path = Path("../gis.csv")
df_gis = pd.read_csv(csv_path,index_col = 0, parse_dates = True, infer_datetime_format = True)
df_gis.head()
# Out:
#             Close
# Date
# 2014-06-02  54.91
# 2014-06-03  55.05
# 2014-06-04  55.56
# 2014-06-05  55.34
# 2014-06-06  55.41

# %%
# Read the third stock
# YOUR CODE HERE
csv_path = Path("../msft.csv")
df_msft = pd.read_csv(csv_path,index_col = 0, parse_dates = True, infer_datetime_format = True)
df_msft.head()
# Out:
#             Close
# Date
# 2014-06-02  40.79
# 2014-06-03  40.29
# 2014-06-04  40.32
# 2014-06-05  41.21
# 2014-06-06  41.48

# %%
csv_path = Path("../nclh.csv")
df_nclh = pd.read_csv(csv_path,index_col = 0, parse_dates = True, infer_datetime_format = True)
df_nclh.head()
# Out:
#             Close
# Date
# 2014-06-02  33.90
# 2014-06-03  34.02
# 2014-06-04  34.09
# 2014-06-05  34.03
# 2014-06-06  33.76

# %%
csv_path = Path("../tsla.csv")
df_tsla = pd.read_csv(csv_path,index_col = 0, parse_dates = True, infer_datetime_format = True)
df_tsla.head()
# Out:
#             Close
# Date
# 2014-06-02  40.94
# 2014-06-03  40.99
# 2014-06-04  40.80
# 2014-06-05  41.38
# 2014-06-06  41.63

# %%
# Concatenate all stocks into a single DataFrame
# YOUR CODE HERE
df_concat = pd.concat([df_aapl,df_gis,df_msft,df_nclh,df_tsla],axis = "columns", join = "inner")
df_concat.head()
# Out:
#             Close  Close  Close  Close  Close
# Date
# 2014-06-02  22.45  54.91  40.79  33.90  40.94
# 2014-06-03  22.77  55.05  40.29  34.02  40.99
# 2014-06-04  23.03  55.56  40.32  34.09  40.80
# 2014-06-05  23.12  55.34  41.21  34.03  41.38
# 2014-06-06  23.06  55.41  41.48  33.76  41.63

# %%
# Reset the index
# YOUR CODE HERE
df_concat.reset_index(inplace = True)
df_concat.head()
# Out:
#         Date  Close  Close  Close  Close  Close
# 0 2014-06-02  22.45  54.91  40.79  33.90  40.94
# 1 2014-06-03  22.77  55.05  40.29  34.02  40.99
# 2 2014-06-04  23.03  55.56  40.32  34.09  40.80
# 3 2014-06-05  23.12  55.34  41.21  34.03  41.38
# 4 2014-06-06  23.06  55.41  41.48  33.76  41.63

# %%
# Pivot so that each column of prices represents a unique symbol
# YOUR CODE HERE
df_concat.columns = ["Date","AAPL","GIS","MSFT","NCLH","TSLA"]
df_concat.head()
# Out:
#         Date   AAPL    GIS   MSFT   NCLH   TSLA
# 0 2014-06-02  22.45  54.91  40.79  33.90  40.94
# 1 2014-06-03  22.77  55.05  40.29  34.02  40.99
# 2 2014-06-04  23.03  55.56  40.32  34.09  40.80
# 3 2014-06-05  23.12  55.34  41.21  34.03  41.38
# 4 2014-06-06  23.06  55.41  41.48  33.76  41.63

# %%
# Drop Nulls
# YOUR CODE HERE
df_concat.dropna(inplace = True)
df_concat.head()
# Out:
#         Date   AAPL    GIS   MSFT   NCLH   TSLA
# 0 2014-06-02  22.45  54.91  40.79  33.90  40.94
# 1 2014-06-03  22.77  55.05  40.29  34.02  40.99
# 2 2014-06-04  23.03  55.56  40.32  34.09  40.80
# 3 2014-06-05  23.12  55.34  41.21  34.03  41.38
# 4 2014-06-06  23.06  55.41  41.48  33.76  41.63

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Calculate weighted portfolio returns
weights = [1/5, 1/5, 1/5,1/5,1/5]
# YOUR CODE HERE

#if index not set to date, need to set for pct_change to work
if type(df_concat.index) == pd.RangeIndex:  
    df_concat.set_index("Date", inplace = True)

daily_returns_ts = df_concat.pct_change()
daily_returns_ts.dropna(inplace = True)
weighted_returns_ts = daily_returns_ts.dot(weights)
weighted_returns_ts.head()
# Out:
# Date
# 2014-06-03    0.001861
# 2014-06-04    0.003770
# 2014-06-05    0.006895
# 2014-06-06    0.000666
# 2014-06-09   -0.001882
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Add your "Custom" portfolio to the larger dataframe of fund returns
# YOUR CODE HERE
daily_returns["Custom"] = weighted_returns_ts
daily_returns.sample(25)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2017-11-20                  -0.002602           -0.006145
# 2016-03-04                   0.004183           -0.003888
# 2015-09-29                  -0.004079           -0.008339
# 2016-11-02                  -0.003884           -0.011511
# 2019-04-11                   0.003406           -0.003959
# 2016-05-17                  -0.004803            0.006704
# 2017-09-29                   0.004561            0.006170
# 2016-10-20                  -0.004313            0.005428
# 2016-07-25                  -0.000404            0.000042
# 2016-11-01                  -0.006986            0.003359
# 2016-05-10                   0.009993            0.010116
# 2016-02-05                  -0.018228           -0.005382
# 2017-02-06                  -0.002982            0.004835
# 2017-12-07                   0.002370           -0.000391
# 2016-04-13                   0.012289            0.005597
# 2016-03-15                  -0.013792           -0.022875
# 2018-09-11                   0.001953           -0.004287
# 2015-09-21                  -0.005189           -0.008370
# 2018-09-19                   0.002123            0.002673
# 2016-06-01                   0.004003            0.011654
# 2015-08-31                  -0.003931           -0.003050
# 2016-08-29                   0.001742           -0.003177
# 2015-03-24                  -0.002571           -0.004808
# 2017-06-02                   0.005967            0.000480
# 2019-02-01                   0.010911            0.006006
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2017-11-20                     0.003831               -0.006602 -0.004989
# 2016-03-04                    -0.000671                0.022272  0.006333
# 2015-09-29                     0.003502               -0.004658 -0.013692
# 2016-11-02                    -0.003375               -0.021001 -0.004244
# 2019-04-11                    -0.000637               -0.000496  0.001705
# 2016-05-17                    -0.032592                0.000119  0.006045
# 2017-09-29                    -0.002374                0.003680 -0.001557
# 2016-10-20                    -0.002777               -0.000892 -0.000235
# 2016-07-25                     0.000778                0.004938 -0.002279
# 2016-11-01                    -0.007216               -0.009591  0.001431
# 2016-05-10                     0.018612                0.014961  0.004689
# 2016-02-05                    -0.017521               -0.066505 -0.017002
# 2017-02-06                    -0.005777               -0.005591 -0.001714
# 2017-12-07                    -0.008949                0.009378 -0.004886
# 2016-04-13                    -0.004322                0.027532  0.006492
# 2016-03-15                     0.000748               -0.011231  0.005307
# 2018-09-11                     0.007189                0.006222  0.001604
# 2015-09-21                     0.006757               -0.006352 -0.001923
# 2018-09-19                    -0.001223                0.005441  0.014688
# 2016-06-01                     0.007321               -0.006107 -0.001828
# 2015-08-31                    -0.004977               -0.019650  0.003630
# 2016-08-29                     0.005003                0.000018  0.003486
# 2015-03-24                    -0.003321               -0.001013  0.008758
# 2017-06-02                     0.006687                0.006871 -0.001769
# 2019-02-01                    -0.002556                0.001810  0.002912
#
#               Algo 2   S&P 500    Custom
# Date
# 2017-11-20  0.007350  0.001276 -0.002483
# 2016-03-04  0.007613  0.003306  0.006720
# 2015-09-29 -0.007279  0.001233 -0.011096
# 2016-11-02 -0.008850 -0.006525 -0.005883
# 2019-04-11 -0.001568  0.000038 -0.003476
# 2016-05-17 -0.007821 -0.009411 -0.014851
# 2017-09-29  0.003380  0.003705  0.003236
# 2016-10-20 -0.000638 -0.001376 -0.003959
# 2016-07-25 -0.003033 -0.003011  0.009006
# 2016-11-01 -0.007888 -0.006787 -0.018242
# 2016-05-10  0.008894  0.012484 -0.001413
# 2016-02-05 -0.015246 -0.018481 -0.040318
# 2017-02-06 -0.001731 -0.002115  0.001792
# 2017-12-07  0.003573  0.002932 -0.003997
# 2016-04-13  0.012362  0.010040  0.013042
# 2016-03-15 -0.011584 -0.001837  0.004610
# 2018-09-11  0.004714  0.003740  0.000379
# 2015-09-21 -0.000271  0.004566  0.012671
# 2018-09-19 -0.001396  0.001253  0.008395
# 2016-06-01  0.006113  0.001130 -0.004666
# 2015-08-31 -0.001487 -0.008392 -0.004122
# 2016-08-29  0.004105  0.005228 -0.004359
# 2015-03-24 -0.000885 -0.006139 -0.001917
# 2017-06-02  0.006703  0.003708  0.008270
# 2019-02-01  0.002222  0.000899 -0.000421

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
# YOUR CODE HERE
daily_returns.dropna(inplace = True)
daily_returns.sample(10)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2019-04-08                   0.000483           -0.000310
# 2017-10-04                   0.000105            0.010585
# 2018-03-15                  -0.004814           -0.004521
# 2016-11-28                  -0.007451           -0.000643
# 2017-02-10                   0.000000            0.000000
# 2016-11-23                   0.000402            0.006624
# 2019-02-28                   0.001146            0.017573
# 2017-08-22                   0.004917            0.005028
# 2018-02-26                   0.003984            0.006145
# 2018-11-05                   0.002988            0.001782
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2019-04-08                     0.000153                0.000841  0.003761
# 2017-10-04                    -0.000932               -0.004590  0.001383
# 2018-03-15                    -0.012433                0.003955 -0.009779
# 2016-11-28                     0.000609               -0.006766  0.015054
# 2017-02-10                     0.000000                0.000000  0.004184
# 2016-11-23                    -0.014641               -0.001677 -0.012352
# 2019-02-28                     0.015376               -0.005387  0.003553
# 2017-08-22                     0.006423                0.013020  0.002447
# 2018-02-26                     0.009546               -0.001412 -0.001839
# 2018-11-05                     0.022700                0.001978  0.008880
#
#               Algo 2   S&P 500    Custom
# Date
# 2019-04-08  0.000218  0.001047  0.004212
# 2017-10-04 -0.002690  0.001247  0.011055
# 2018-03-15 -0.001499 -0.000782 -0.005293
# 2016-11-28 -0.013343 -0.005254 -0.003796
# 2017-02-10  0.006009  0.003566 -0.002607
# 2016-11-23  0.006259  0.000808 -0.006436
# 2019-02-28 -0.002877 -0.002826  0.003447
# 2017-08-22  0.008463  0.009941  0.012636
# 2018-02-26  0.005430  0.011757  0.004135
# 2018-11-05 -0.000330  0.005600 -0.000951

# %% [markdown]
# ## Re-run the performance and risk analysis with your portfolio to see how it compares to the others

# %%
# Risk
# YOUR CODE HERE
dr_std = daily_returns.std()
dr_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# S&P 500                        0.008554
# Custom                         0.012008
# dtype: float64

# %%
# Rolling
# YOUR CODE HERE
win = 21
rolling_21 = daily_returns.rolling(window = win).std()
rolling_21.plot(figsize = (15,10))

# %%
# Annualized Sharpe Ratios
# YOUR CODE HERE
sharpe = (daily_returns.mean() * T_DAYS) / (daily_returns.std() * np.sqrt(T_DAYS))
sharpe
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# S&P 500                        0.648267
# Custom                         0.716571
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
# YOUR CODE HERE
sharpe.plot.bar(figsize = (8,5))

# %%
# Create a correlation analysis
# YOUR CODE HERE
dr_corr = daily_returns.corr()
dr_corr
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# S&P 500                                       0.837864            0.669732
# Custom                                        0.672796            0.511968
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# Algo 2                                          0.507414
# S&P 500                                         0.623946
# Custom                                          0.532746
#
#                              BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# SOROS FUND MANAGEMENT LLC                  0.754360  0.321211  0.826873
# PAULSON & CO.INC.                          0.545623  0.268840  0.678152
# TIGER GLOBAL MANAGEMENT LLC                0.424423  0.164387  0.507414
# BERKSHIRE HATHAWAY INC                     1.000000  0.292033  0.688082
# Algo 1                                     0.292033  1.000000  0.288243
# Algo 2                                     0.688082  0.288243  1.000000
# S&P 500                                    0.751371  0.279494  0.858764
# Custom                                     0.684334  0.215917  0.665355
#
#                               S&P 500    Custom
# SOROS FUND MANAGEMENT LLC    0.837864  0.672796
# PAULSON & CO.INC.            0.669732  0.511968
# TIGER GLOBAL MANAGEMENT LLC  0.623946  0.532746
# BERKSHIRE HATHAWAY INC       0.751371  0.684334
# Algo 1                       0.279494  0.215917
# Algo 2                       0.858764  0.665355
# S&P 500                      1.000000  0.785482
# Custom                       0.785482  1.000000

# %%
sns.heatmap(dr_corr, vmin = -1, vmax = 1)

# %%
# Beta
# YOUR CODE HERE

ticker = "Custom"
win = 60

cov = daily_returns[ticker].cov(daily_returns[IND])
var = daily_returns[ticker].var()

beta = cov / var

rolling_cov = daily_returns[ticker].rolling(window=win).cov(daily_returns[IND])
rolling_cov.sort_index(inplace = True)
rolling_var = daily_returns[IND].rolling(window=win).var()
rolling_var.sort_index(inplace = True)
rolling_beta = rolling_cov / rolling_var

rolling_beta.plot(figsize = [15,10], title = f"Rolling {win}-day Beta for {ticker.title()}")

# %%
# Overall performance of the custom portfolio was quite good.  It has a low correlation compared to all other portfolios except for Algo 1,
# and also has the highest Sharpe ratio other than Algo 1.  While the standard deviation was the 2nd highest behing Bershire Hathaway,
# the additional return was enough to compensate for the volatility.  This portfolio was designed with 3 tech stocks, 1 completely unrelated
# food producer stock for stability, and one contra stock where the returns have been declining, but reduced the beta to offset the others.
